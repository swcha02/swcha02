# %% [markdown]
# # "Pyfolio"
# > "KOSPI"
#
# - toc:true- branch: master
# - badges: true
# - comments: true
# - author: swcha02
# - categories: [Finance,Python]

# %%
import FinanceDataReader as fdr
import pyfolio as pf 
import numpy as np
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
ks11 = fdr.DataReader("KS11")["Close"].pct_change().dropna()

# %%
pf.create_returns_tear_sheet(ks11)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>1981-05-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-07-02</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>511</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>8.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>2555.2%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>23.2%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-75.4%</td>
#     </tr>
#     <tr>
# ...
